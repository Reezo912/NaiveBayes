# %% [markdown]
# # Google Play Store Review Analysis

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split



pd.set_option('display.max_colwidth', None)

# %%
url = 'https://raw.githubusercontent.com/4GeeksAcademy/naive-bayes-project-tutorial/main/playstore_reviews.csv'

df = pd.read_csv(url)

df.to_csv('../data/raw/PlayStoreDataset.csv')

# %%
df.sample(10)
# Out:
#                    package_name  \
# 719       com.opera.mini.native
# 238  com.supercell.clashofclans
# 212  com.supercell.clashofclans
# 89         com.linkedin.android
# 644           com.uc.browser.en
# 265          com.android.chrome
# 88         com.linkedin.android
# 826              com.hamropatro
# 345              com.viber.voip
# 237  com.supercell.clashofclans
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         review  \
# ...

# %% [markdown]
# Dropeo la columna identificativa de cada app

# %%
df.drop('package_name', inplace=True, axis=1)

# %% [markdown]
# Compruebo si tengo valores missing

# %%
df.isna().sum().sort_values()
# Out:
# review      0
# polarity    0
# dtype: int64

# %%
df['review']= df["review"].str.strip().str.lower()

# %% [markdown]
# ### Divido el Dataset

# %%
x = df['review']
y = df['polarity']

X_train, X_test, y_train, y_test =  train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Vectorizo

# %%
from sklearn.feature_extraction.text import CountVectorizer

vec_model = CountVectorizer(stop_words='english')
X_train = vec_model.fit_transform(X_train).toarray()
X_test = vec_model.transform(X_test).toarray()

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.8156424581005587

# %% [markdown]
# Esta es mi puntuacion sin realizar optimizaciones. En otro notebook realizare optimizaciones en mi dataset para obtener mejor resultado. En caso de obtenerlo optimizare sobre ese dataset

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB



model_Gauss = GaussianNB()
model_Gauss.fit(X_train, y_train)
y_pred = model_Gauss.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.8044692737430168
